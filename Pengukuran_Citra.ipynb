# %% [markdown]
# <a href="https://colab.research.google.com/github/Indri211/UAS_Kriptografi/blob/main/Pengukuran_Citra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from matplotlib import pyplot as plt


gambar = cv2.imread('foto.jpg')

gambar_abu = cv2.cvtColor(gambar, cv2.COLOR_BGR2GRAY)

plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(gambar, cv2.COLOR_BGR2RGB))
plt.title('Gambar Asli')


plt.subplot(1, 2, 2)
plt.imshow(gambar_abu, cmap='gray')
plt.title('Citra Abu-abu')

plt.show()
